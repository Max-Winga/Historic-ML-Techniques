# %% [markdown]
# # Imports and Helper Functions

# %%
## Imports
import numpy as np
import math as m
import pylab as plt
import pickle
import sys
from matplotlib.animation import FuncAnimation
import time as t

# %%
def forward_diffusion(x0, T, delta):
    xs = [x0]
    for _ in range(T):
        xo = xs[-1]
        xs.append(xo + (delta/2)*-xo + m.sqrt(delta)*np.random.normal(0, 1))
    return xs

# %%
# samples = forward_diffusion(10, 3000000, 0.05)[1000:]
plt.figure()
plt.hist(samples, density=True, bins=200, label="Samples")
mu = 0
sigma = 1
x = np.linspace(-5, 5, 1000)
pdf = (1 / (np.sqrt(2 * np.pi))) * np.exp(-0.5 * x**2)
plt.plot(x, pdf, label='Normal Distribution')
plt.legend()
plt.show()

# %%
def approach_2(x0, T, delta):
    xs = [x0]
    for _ in range(T):
        xn = xs[-1] + m.sqrt(delta)*np.random.normal(0, 1)
        if np.exp((xs[-1]**2 - xn**2)/2) > np.random.rand():
            xs.append(xn)
    return xs

# %%
samples = approach_2(10, 1000000, 1)[1000:]
plt.figure()
plt.hist(samples, density=True, bins=200, label="Samples")
mu = 0
sigma = 1
x = np.linspace(-5, 5, 1000)
pdf = (1 / (1 * np.sqrt(2 * np.pi))) * np.exp(-0.5 * x**2)
plt.plot(x, pdf, label='Normal Distribution')
plt.legend()
plt.show()

# %%
def approach_2_2(x0, T, d):
    xs = [x0]
    for _ in range(T):
        xo = xs[-1]
        xn = xo + (d/2)*-xo + np.random.normal(0, m.sqrt(d))
        A = np.exp(d*(xo - xn)*((-xo) + (-xn)) + ((d/2)**2)*(xo**2 - xn**2))
        if A > np.random.rand():
            xs.append(xn)
    return xs

# %%
T = 1000000
samples = approach_2_2(1, T, 0.005)
print(f"Acceptance Rate = {len(samples)/T}")
plt.figure()
plt.plot()
plt.hist(samples, density=True, bins=200, label='Samples')
mu = 0
sigma = 1
x = np.linspace(-5, 5, 1000)
pdf = (1 / (1 * np.sqrt(2 * np.pi))) * np.exp(-0.5 * x**2)
plt.plot(x, pdf, label='Normal Distribution')
plt.legend()
plt.show()
# Out:
# Acceptance Rate = 0.999755

# %%
def forward_diffusion_2(x0, timesteps):
    xs = [x0]
    B = np.linspace(0.0001, 0.02, timesteps,dtype=np.float32)
    for i in range(timesteps):
        xo = xs[-1]
        xs.append(xo*np.sqrt(1-B[i]) + np.sqrt(B[i])*np.random.normal(0, 1))
    return xs

def forward_diffusion_3(x0, timesteps):
    x = x0
    B = np.linspace(0.0001, 0.02, timesteps,dtype=np.float32)
    for i in range(timesteps):
        x = x*np.sqrt(1-B[i]) + np.sqrt(B[i])*np.random.normal(0, 1)
    return x

# %%
n = 8
plt.figure()
for i in range(n):
    run = forward_diffusion_2((np.random.rand()-0.5)*40, 7500)
    plt.plot(run, label=f'Run {i}')
plt.legend()
plt.title(f"{n} Runs of Forward Diffusion")
plt.xlabel("Timestep")
plt.ylabel("X position")
plt.show()

# %%
results = []
for i in range(10000):
    results.append(forward_diffusion_3(0, 199))
print("here")
plt.figure()
plt.plot()
plt.hist(samples, density=True, bins=200, label='Samples')
mu = 0
sigma = 1
x = np.linspace(-5, 5, 1000)
pdf = (1 / (1 * np.sqrt(2 * np.pi))) * np.exp(-0.5 * x**2)
plt.plot(x, pdf, label='Normal Distribution')
plt.legend()
plt.show()
# Out:
# here

# %%
def forward_diffusion_4(x0, timesteps):
    B = np.linspace(0.0001, 0.02, timesteps,dtype=np.float32)
    a = [1-b for b in B]
    a_T = np.prod(a)
    return np.sqrt(a_T)*x0 + np.sqrt(1-a_T)*np.random.normal(0, 1)

# %%
results = []
for i in range(100000):
    results.append(forward_diffusion_4(0, 199))
print("here")
plt.figure()
plt.plot()
plt.hist(samples, density=True, bins=200, label='Samples')
mu = 0
sigma = 1
x = np.linspace(-5, 5, 1000)
pdf = (1 / (1 * np.sqrt(2 * np.pi))) * np.exp(-0.5 * x**2)
plt.plot(x, pdf, label='Normal Distribution')
plt.legend()
plt.show()
# Out:
# here
